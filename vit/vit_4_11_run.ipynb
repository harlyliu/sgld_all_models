# %%
# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "" # Forces the code to ignore the GPU and use CPU
from ViT_classes_4_4_2026 import *

# %%
experiment = Experiment()
experiment.run_whole_experiment(
    sample_size=2000,
    data_type='npz',
    seed=20,
    true_r2=0.80,
    in_feature_list=[50, 100],
    lr=1e-2,
    epochs=30
)
# Out:
# Epoch 0, r2_train=-0.00942981243133545
# Epoch 0, r2_val=-0.0035506486892700195
# Epoch 0, time=15.94s
# Epoch 10, r2_train=-0.0004788637161254883
# Epoch 10, r2_val=-0.0013804435729980469
# Epoch 10, time=171.78s
# Epoch 20, r2_train=0.005053877830505371
# Epoch 20, r2_val=9.28044319152832e-05
# Epoch 20, time=329.29s
# Sample Size: 2000
# Average r2_train: 0.00169295072555542
# Average r2_val: 0.0016248822212219238
