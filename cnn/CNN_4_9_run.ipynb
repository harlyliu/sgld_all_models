# %%
from Cnn_classes_4_9 import *

# %%
all_experiments=[]
for seed in range(15,20):
    print(seed+1)
    experiment = Experiment()
    experiment.run_whole_experiment(
        seed=seed+1,
        sample_size=2000,
        true_r2=0.80,
        in_feature_list=[50, 100],
        lr=1e-3,
        epochs=150
    )
    all_experiments.append(experiment)
# Out:
# 16
# Epoch 0, r2_train=-1.1263022422790527
# Epoch 0, r2_val=0.003820478916168213
# Epoch 0, time=1.08s
# Epoch 10, r2_train=0.9742922782897949
# Epoch 10, r2_val=0.28087860345840454
# Epoch 10, time=11.79s
# Epoch 20, r2_train=0.9725294709205627
# Epoch 20, r2_val=0.3006487488746643
# Epoch 20, time=22.57s
# Epoch 30, r2_train=0.9856445789337158
# Epoch 30, r2_val=0.3525007963180542
# Epoch 30, time=33.36s
# Epoch 40, r2_train=0.9635075926780701
# Epoch 40, r2_val=0.2840864062309265
# Epoch 40, time=44.08s
# Epoch 50, r2_train=0.9815282821655273
# Epoch 50, r2_val=0.3480163812637329
# Epoch 50, time=54.75s
# Epoch 60, r2_train=0.9869042634963989
# Epoch 60, r2_val=0.39313846826553345
# Epoch 60, time=65.43s
# Epoch 70, r2_train=0.986746609210968
# Epoch 70, r2_val=0.4002794623374939
# Epoch 70, time=76.12s
# Epoch 80, r2_train=0.9885275363922119
# Epoch 80, r2_val=0.4018988609313965
# Epoch 80, time=86.82s
# Epoch 90, r2_train=0.9883615374565125
# Epoch 90, r2_val=0.42594945430755615
# Epoch 90, time=97.53s
# Epoch 100, r2_train=0.9617114067077637
# Epoch 100, r2_val=0.4022294878959656
# Epoch 100, time=108.24s
# Epoch 110, r2_train=0.9535309672355652
# Epoch 110, r2_val=0.2213870882987976
# Epoch 110, time=118.96s
# Epoch 120, r2_train=0.9629511833190918
# Epoch 120, r2_val=0.36592036485671997
# Epoch 120, time=129.60s
# Epoch 130, r2_train=0.9800795316696167
# Epoch 130, r2_val=0.34893280267715454
# Epoch 130, time=140.27s
# Epoch 140, r2_train=0.990308403968811
# Epoch 140, r2_val=0.41565006971359253
# Epoch 140, time=150.96s
# Sample Size: 2000
# Average r2_train: 0.9668349027633667
# Average r2_val: 0.27986717224121094
# 17
# Epoch 0, r2_train=-2.7790942192077637
# Epoch 0, r2_val=-1.4820668697357178
# Epoch 0, time=1.06s
# Epoch 10, r2_train=0.9641909599304199
# Epoch 10, r2_val=0.23543810844421387
# Epoch 10, time=11.71s
# Epoch 20, r2_train=0.9711606502532959
# Epoch 20, r2_val=0.24001526832580566
# Epoch 20, time=22.37s
# Epoch 30, r2_train=0.9770976901054382
# Epoch 30, r2_val=0.3225213289260864
# Epoch 30, time=33.06s
# Epoch 40, r2_train=0.9528865814208984
# Epoch 40, r2_val=0.27045512199401855
# Epoch 40, time=43.69s
# Epoch 50, r2_train=0.9865375757217407
# Epoch 50, r2_val=0.35492926836013794
# Epoch 50, time=54.36s
# Epoch 60, r2_train=0.9596914052963257
# Epoch 60, r2_val=0.3437570333480835
# Epoch 60, time=65.01s
# Epoch 70, r2_train=0.9886503219604492
# Epoch 70, r2_val=0.36269867420196533
# Epoch 70, time=75.68s
# Epoch 80, r2_train=0.9853212833404541
# Epoch 80, r2_val=0.3602030873298645
# Epoch 80, time=86.37s
# Epoch 90, r2_train=0.9887288212776184
# Epoch 90, r2_val=0.3652052879333496
# Epoch 90, time=97.03s
# Epoch 100, r2_train=0.9851926565170288
# Epoch 100, r2_val=0.37275516986846924
# Epoch 100, time=107.68s
# Epoch 110, r2_train=0.990432858467102
# Epoch 110, r2_val=0.4018925428390503
# Epoch 110, time=118.31s
# Epoch 120, r2_train=0.987551212310791
# Epoch 120, r2_val=0.37393665313720703
# Epoch 120, time=128.97s
# Epoch 130, r2_train=0.9856364130973816
# Epoch 130, r2_val=0.3924732804298401
# Epoch 130, time=139.58s
# Epoch 140, r2_train=0.9885464310646057
# Epoch 140, r2_val=0.3962114453315735
# Epoch 140, time=150.29s
# Sample Size: 2000
# Average r2_train: 0.9902900457382202
# Average r2_val: 0.33626532554626465
# 18
# Epoch 0, r2_train=-1.5198547840118408
# Epoch 0, r2_val=-0.1133650541305542
# Epoch 0, time=1.07s
# Epoch 10, r2_train=0.9756319522857666
# Epoch 10, r2_val=0.2481655478477478
# Epoch 10, time=11.82s
# Epoch 20, r2_train=0.9794905185699463
# Epoch 20, r2_val=0.2745221257209778
# Epoch 20, time=22.59s
# Epoch 30, r2_train=0.9834697842597961
# Epoch 30, r2_val=0.31412702798843384
# Epoch 30, time=33.37s
# Epoch 40, r2_train=0.9671810269355774
# Epoch 40, r2_val=0.3402720093727112
# Epoch 40, time=44.19s
# Epoch 50, r2_train=0.9683020710945129
# Epoch 50, r2_val=0.2608852982521057
# Epoch 50, time=54.96s
# Epoch 60, r2_train=0.9799371361732483
# Epoch 60, r2_val=0.3693234324455261
# Epoch 60, time=65.75s
# Epoch 70, r2_train=0.9889060258865356
# Epoch 70, r2_val=0.38176149129867554
# Epoch 70, time=76.61s
# Epoch 80, r2_train=0.9501466155052185
# Epoch 80, r2_val=0.2682848572731018
# Epoch 80, time=87.43s
# Epoch 90, r2_train=0.9900268912315369
# Epoch 90, r2_val=0.3971952199935913
# Epoch 90, time=98.26s
# Epoch 100, r2_train=0.9760962724685669
# Epoch 100, r2_val=0.34720832109451294
# Epoch 100, time=109.06s
# Epoch 110, r2_train=0.9874684810638428
# Epoch 110, r2_val=0.4105531573295593
# Epoch 110, time=119.81s
# Epoch 120, r2_train=0.992383599281311
# Epoch 120, r2_val=0.42634254693984985
# Epoch 120, time=130.65s
# Epoch 130, r2_train=0.9865120649337769
# Epoch 130, r2_val=0.39218056201934814
# Epoch 130, time=141.52s
# Epoch 140, r2_train=0.9891555905342102
# Epoch 140, r2_val=0.41794532537460327
# Epoch 140, time=152.42s
# Sample Size: 2000
# Average r2_train: 0.9811801910400391
# Average r2_val: 0.3993297219276428
# 19
# Epoch 0, r2_train=-2.0955121517181396
# Epoch 0, r2_val=-0.35618627071380615
# Epoch 0, time=1.07s
# Epoch 10, r2_train=0.9636752605438232
# Epoch 10, r2_val=0.24439239501953125
# Epoch 10, time=11.77s
# Epoch 20, r2_train=0.9722854495048523
# Epoch 20, r2_val=0.27753788232803345
# Epoch 20, time=22.50s
# Epoch 30, r2_train=0.9805074334144592
# Epoch 30, r2_val=0.322517454624176
# Epoch 30, time=33.18s
# Epoch 40, r2_train=0.9631607532501221
# Epoch 40, r2_val=0.2709825038909912
# Epoch 40, time=43.87s
# Epoch 50, r2_train=0.9887811541557312
# Epoch 50, r2_val=0.370469868183136
# Epoch 50, time=54.56s
# Epoch 60, r2_train=0.9910423159599304
# Epoch 60, r2_val=0.37027931213378906
# Epoch 60, time=65.23s
# Epoch 70, r2_train=0.9889072775840759
# Epoch 70, r2_val=0.37020450830459595
# Epoch 70, time=75.95s
# Epoch 80, r2_train=0.9692482352256775
# Epoch 80, r2_val=0.3694300055503845
# Epoch 80, time=86.66s
# Epoch 90, r2_train=0.9866650700569153
# Epoch 90, r2_val=0.3758191466331482
# Epoch 90, time=97.35s
# Epoch 100, r2_train=0.9833478331565857
# Epoch 100, r2_val=0.3773493766784668
# Epoch 100, time=108.09s
# Epoch 110, r2_train=0.9676178693771362
# Epoch 110, r2_val=0.38142842054367065
# Epoch 110, time=118.81s
# Epoch 120, r2_train=0.9918889403343201
# Epoch 120, r2_val=0.39795076847076416
# Epoch 120, time=129.46s
# Epoch 130, r2_train=0.9889145493507385
# Epoch 130, r2_val=0.3997557759284973
# Epoch 130, time=140.13s
# Epoch 140, r2_train=0.9849357604980469
# Epoch 140, r2_val=0.34732139110565186
# Epoch 140, time=150.79s
# Sample Size: 2000
# Average r2_train: 0.988389790058136
# Average r2_val: 0.3826730251312256
# 20
# Epoch 0, r2_train=-1.8320467472076416
# Epoch 0, r2_val=-0.3110849857330322
# Epoch 0, time=1.08s
# Epoch 10, r2_train=0.9651910662651062
# Epoch 10, r2_val=0.15663784742355347
# Epoch 10, time=11.79s
# Epoch 20, r2_train=0.9741920232772827
# Epoch 20, r2_val=0.18856406211853027
# Epoch 20, time=22.50s
# Epoch 30, r2_train=0.9851771593093872
# Epoch 30, r2_val=0.23974061012268066
# Epoch 30, time=33.21s
# Epoch 40, r2_train=0.9751225113868713
# Epoch 40, r2_val=0.22016894817352295
# Epoch 40, time=43.89s
# Epoch 50, r2_train=0.9843360781669617
# Epoch 50, r2_val=0.2578706741333008
# Epoch 50, time=54.64s
# Epoch 60, r2_train=0.9821733236312866
# Epoch 60, r2_val=0.285724401473999
# Epoch 60, time=65.37s
# Epoch 70, r2_train=0.9754212498664856
# Epoch 70, r2_val=0.2856367230415344
# Epoch 70, time=76.05s
# Epoch 80, r2_train=0.9831711053848267
# Epoch 80, r2_val=0.28729248046875
# Epoch 80, time=86.81s
# Epoch 90, r2_train=0.9757894277572632
# Epoch 90, r2_val=0.2960660457611084
# Epoch 90, time=97.48s
# Epoch 100, r2_train=0.982327401638031
# Epoch 100, r2_val=0.2925897240638733
# Epoch 100, time=108.19s
# Epoch 110, r2_train=0.991117000579834
# Epoch 110, r2_val=0.33515506982803345
# Epoch 110, time=118.99s
# Epoch 120, r2_train=0.9808799624443054
# Epoch 120, r2_val=0.3136298656463623
# Epoch 120, time=129.72s
# Epoch 130, r2_train=0.9870542287826538
# Epoch 130, r2_val=0.335369348526001
# Epoch 130, time=140.48s
# Epoch 140, r2_train=0.9912282824516296
# Epoch 140, r2_val=0.3512434959411621
# Epoch 140, time=151.21s
# Sample Size: 2000
# Average r2_train: 0.9900593161582947
# Average r2_val: 0.3392608165740967

# %%
plt.plot(experiment.trainers[0].r2_val)
plt.show()

# %%
plt.plot(experiment.trainers[0].r2_train)
plt.show()
