# %%
from DNN_classes_4_11 import *

# %%
# experiment = Experiment()
# experiment.run_whole_experiment(
#     seed=3,
#     sample_size= 2000,
#     true_r2=0.80,
#     in_feature_list=[50, 100],
#     lr=1e-4,
#     epochs=100
# )

# %%
# plt.plot(experiment.trainers[0].r2_val)
# # plt.ylim(0,1)
# plt.show()

# %%
# plt.plot(experiment.trainers[0].r2_train)
# # plt.ylim(0,1)
# plt.show()

# %%
all_experiments=[]
for seed in range(15, 20):
    print(f"seed:{seed+1}")
    experiment = Experiment()
    experiment.run_whole_experiment(
        seed=seed+1,
        sample_size= 2000,
        true_r2=0.80,
        in_feature_list=[50, 100],
        lr=1e-4,
        epochs=100
    )
    all_experiments.append(experiment)
# Out:
# seed:16
# Epoch 0, r2_train=0.1543000340461731
# Epoch 0, r2_val=-0.03629457950592041
# Epoch 0, time=0.50s
# Epoch 10, r2_train=0.7084941864013672
# Epoch 10, r2_val=-0.07744348049163818
# Epoch 10, time=3.56s
# Epoch 20, r2_train=0.8602015376091003
# Epoch 20, r2_val=-0.07574498653411865
# Epoch 20, time=6.67s
# Epoch 30, r2_train=0.9148547649383545
# Epoch 30, r2_val=-0.0668184757232666
# Epoch 30, time=9.69s
# Epoch 40, r2_train=0.9311034083366394
# Epoch 40, r2_val=-0.07749521732330322
# Epoch 40, time=12.69s
# Epoch 50, r2_train=0.9316991567611694
# Epoch 50, r2_val=-0.07577633857727051
# Epoch 50, time=15.73s
# Epoch 60, r2_train=0.9433690905570984
# Epoch 60, r2_val=-0.03853118419647217
# Epoch 60, time=18.79s
# Epoch 70, r2_train=0.9575666189193726
# Epoch 70, r2_val=-0.026672959327697754
# Epoch 70, time=21.82s
# Epoch 80, r2_train=0.9583892226219177
# Epoch 80, r2_val=-0.02098715305328369
# Epoch 80, time=24.85s
# Epoch 90, r2_train=0.9599182605743408
# ...
